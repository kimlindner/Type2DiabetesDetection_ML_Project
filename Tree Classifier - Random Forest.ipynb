# %% [markdown]
# # DecisionTree Classifier & Random Forest Classifier

# %% [markdown]
# ## 1) Importing Packages

# %%
#packages for handling the data
import numpy as np
import pandas as pd


#packages for plotting/visualization
import matplotlib.pyplot as plt

#packages for both models
from sklearn import tree
from sklearn import ensemble

#train/test data import
from ipynb.fs.full.Functions import load_train_test_data
from ipynb.fs.full.Functions import model_eval

#evaluation packages
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import f1_score
# from sklearn.metrics import precision_score 
# from sklearn.metrics import recall_score 
# from sklearn.metrics import confusion_matrix

# %% [markdown]
# <div style="border-bottom: 3px solid black; margin-bottom:5px"></div>
# <div style="border-bottom: 3px solid black"></div>
#
# ## 2) Models

# %% [markdown]
# This section will be divided into one samller section for data loading and other two similar sections, one for Decision Tree and the other for the Random Forest

# %% [markdown]
# <div style="border-bottom: 3px solid black; margin-bottom:5px"></div>
#
# ### 2.1) Loading Data

# %%
X_train, X_test, y_train, y_test = load_train_test_data()
# Out:
# A snippet of our training data:
#      Age  PhysicallyActive       BMI     Sleep  SoundSleep  JunkFood  Stress  \
# 16   2.0               2.0 -0.697273  0.022886    0.256854       0.0     1.0
# 110  2.0               1.0  0.428174  0.022886   -0.812113       0.0     2.0
# 28   1.0               0.0  0.615748 -0.786704    0.256854       0.0     0.0
# 74   2.0               0.0  0.990897  0.022886    0.256854       0.0     3.0
# 147  0.0               1.0  0.428174  0.832476    1.325822       0.0     1.0
#
#      BPLevel  Pregnancies  UrinationFreq  BMI_high  Family_Diabetes_yes  \
# 16       1.0    -0.413322            0.0         0                  1.0
# 110      2.0    -0.413322            1.0         1                  1.0
# 28       1.0    -0.413322            0.0         1                  1.0
# 74       2.0    -0.413322            0.0         1                  1.0
# 147      1.0    -0.413322            1.0         1                  0.0
#
#      Pdiabetes_yes  Smoking_yes  RegularMedicine_yes  Alcohol_yes  \
# 16             0.0          0.0                  0.0          0.0
# 110            0.0          0.0                  1.0          0.0
# 28             0.0          0.0                  0.0          0.0
# 74             0.0          0.0                  1.0          1.0
# 147            0.0          0.0                  1.0          0.0
#
#      Gender_Male  highBP_yes
# 16           1.0         0.0
# 110          0.0         0.0
# 28           1.0         0.0
# 74           1.0         1.0
# 147          1.0         0.0
# There are 240 entries with 18 columns in our training data.
# There are 43 entries with 18 columns in our testing data.

# %% [markdown]
# <div style="border-bottom: 3px solid black; margin-bottom:5px"></div>
#
# ### 2.2) Decision Tree Classifier

# %%
dtc = tree.DecisionTreeClassifier(random_state=0)

# %%
#raw training
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
plt.figure(figsize=(18,12))
print(f' Number of leaves: {dtc.get_n_leaves()}\n Depth of the tree: {dtc.get_depth()}\n General structure of the generated tree:\n')
x = tree.plot_tree(dtc)
# Out:
#  Number of leaves: 57
#  Depth of the tree: 13
#  General structure of the generated tree:

# %%
model_eval(dtc,X_train, X_test, y_train, y_test,confusion=True,roc=True)
# Out:
# Evaluation: accuracy_score
# 93.33% for the train data
# 72.09% for the test data
#
# Evaluation: f1_score
# 88.41% for the train data
# 40.00% for the test data
#
# Evaluation: recall_score
# 79.22% for the train data
# 28.57% for the test data
#
# Evaluation: precision_score
# 100.00% for the train data
# 66.67% for the test data
#
# Evaluation: confusion_matrix
# Evaluation: roc
# [(0.9333333333333333, 0.7209302325581395),
#  (0.8840579710144928, 0.4),
#  (0.7922077922077922, 0.2857142857142857),
#  (1.0, 0.6666666666666666)]

# %% [markdown]
# <div style="border-bottom: 3px solid black; margin-bottom:5px"></div>
#
# ### 2.3) Random Forest Classifier

# %%
rfc = ensemble.RandomForestClassifier(random_state=0,n_estimators=5,bootstrap=False,max_depth=10,warm_start=True
                                     ,max_leaf_nodes=None,criterion='gini',ccp_alpha=.001)

# %%
#raw training
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.001, max_depth=10,
#                        n_estimators=5, random_state=0, warm_start=True)

# %%
model_eval(rfc,X_train, X_test, y_train, y_test,confusion=True,roc=True)
# Out:
# Evaluation: accuracy_score
# 93.33% for the train data
# 74.42% for the test data
#
# Evaluation: f1_score
# 89.61% for the train data
# 52.17% for the test data
#
# Evaluation: recall_score
# 89.61% for the train data
# 42.86% for the test data
#
# Evaluation: precision_score
# 89.61% for the train data
# 66.67% for the test data
#
# Evaluation: confusion_matrix
# Evaluation: roc
# [(0.9333333333333333, 0.7441860465116279),
#  (0.8961038961038962, 0.5217391304347826),
#  (0.8961038961038961, 0.42857142857142855),
#  (0.8961038961038961, 0.6666666666666666)]
