# %%
pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\kim-carolin\anaconda3\lib\site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ipynb.fs.full.Functions import load_train_test_data

# %%
X_train, X_test, y_train, y_test = load_train_test_data()
# Out:
# A snippet of our training data:
#       Age  PhysicallyActive       BMI     Sleep  SoundSleep  JunkFood  Stress  \
# 554   0.0               3.0  0.774930  0.053296   -1.347851       0.0     1.0
# 46    2.0               3.0  2.295772  0.805294    0.235535       0.0     2.0
# 968   2.0               0.0  0.965035  0.053296    0.235535       0.0     3.0
# 816   2.0               2.0  0.204615  0.053296   -0.292260       0.0     1.0
# 1120  3.0               2.0  0.014510  0.805294   -1.347851       0.0     1.0
#
#       BPLevel  Pregnancies  UrinationFreq  Pdiabetes_yes  highBP_yes  \
# 554       1.0    -0.476208            0.0            0.0         1.0
# 46        1.0    -0.476208            0.0            0.0         0.0
# 968       2.0    -0.476208            0.0            0.0         1.0
# 816       2.0    -0.476208            0.0            0.0         1.0
# 1120      1.0    -0.476208            1.0            0.0         0.0
#
#       Family_Diabetes_yes  Alcohol_yes  RegularMedicine_yes  Smoking_yes  \
# 554                   0.0          0.0                  0.0          0.0
# 46                    1.0          1.0                  1.0          0.0
# 968                   1.0          1.0                  1.0          0.0
# 816                   1.0          1.0                  0.0          0.0
# 1120                  1.0          1.0                  1.0          0.0
#
#       Gender_Male  BMI_high
# 554           0.0         1
# 46            1.0         1
# 968           1.0         1
# 816           1.0         1
# 1120          1.0         1
# There are 1091 entries with 18 columns in our training data.
# There are 193 entries with 18 columns in our testing data.
